# %%
import time

for x in "Welcome to Wafer Yield Calculator\n":
    print(x, end='')
    time.sleep(0.05)
    
time.sleep (1)

for x in "In this project, you will type in:\n":
    print(x, end='')
    time.sleep(0.05)

time.sleep(1)

for x in "D - Defect density (defects per square centimeter)\n":
     print(x, end='')
     time.sleep(0.05)

time.sleep(1)

for x in "A - Area of die (in square centimeters)\n":
        print(x, end='')
        time.sleep(0.05)

time.sleep(1)

for x in "To calculate the yield of your wafer.":
        print(x, end='')
        time.sleep(0.05)

# %%
import math
def wafer_yield(D, A):
    return math.exp(-D*A) * 100
    
answer = wafer_yield(0.3, 0.5)
print("Wafer yield is:", answer, "%")
